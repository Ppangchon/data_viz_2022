# %% [markdown]
# <a href="https://colab.research.google.com/github/Ppangchon/data_viz_2022/blob/main/starclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 281.3 MB 56 kB/s
# ...
#      |████████████████████████████████| 199 kB 88.7 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=ff278b775621d223e780b71be2dc9c378267d1779dab13215b950fcc8430c021
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# ...

# %%
from pyspark import SparkContext
from pyspark.sql.functions import *

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.ml.feature import StringIndexer
from pyspark.sql import SQLContext, SparkSession
spark = SparkSession.Builder().appName('Project').getOrCreate()

# %%
from pyspark.ml.feature import MinMaxScaler, VectorAssembler
from pyspark.ml.linalg import DenseMatrix, Vectors
from pyspark.ml.stat import Correlation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os #os จัดการไฟล์ในคอมพิวเตอร์

# %%
path = '/content/drive/My Drive/classification'

# %%
df = os.path.join(path,'star_classification.csv') 
print(df)
# Out:
# /content/drive/My Drive/classification/star_classification.csv

# %%
a = path + '/star_classification.csv' 
print(a)
# Out:
# /content/drive/My Drive/classification/star_classification.csv

# %%
data = pd.read_csv(df) 
data
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# ...

# %%
data.head(20) #.head ใช้ดูหัวตาราง
# Out:
#           obj_ID       alpha      delta         u         g         r  \
# 0   1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1   1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2   1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3   1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4   1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# 5   1.237680e+18  340.995121  20.589476  23.48827  23.33776  21.32195
# 6   1.237679e+18   23.234926  11.418188  21.46973  21.17624  20.92829
# 7   1.237679e+18    5.433176  12.065186  22.24979  22.02172  20.34126
# 8   1.237661e+18  200.290475  47.199402  24.40286  22.35669  20.61032
# 9   1.237671e+18   39.149691  28.102842  21.74669  20.03493  19.17553
# 10  1.237680e+18  328.092076  18.220310  25.77163  22.52042  20.63884
# 11  1.237662e+18  243.986637  25.738280  23.76761  23.79969  20.98318
# ...

# %%
data.tail()
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 99995  21.30548  20.73569    7778       301        2       581  1.055431e+19
# 99996  19.75759  19.41526    7917       301        1       289  8.586351e+18
# 99997  17.69034  17.35221    5314       301        4       308  3.112008e+18
# 99998  19.07254  18.62482    3650       301        4       131  7.601080e+18
# 99999  20.00959  19.28075    3650       301        4        60  8.343152e+18
#
#         class  redshift  plate    MJD  fiber_ID
# ...

# %%
data.shape #shape ใช้แสดงว่ามีกี่ row กี่ colum
# Out:
# (100000, 18)
